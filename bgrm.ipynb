# %% [markdown]
# <a href="https://colab.research.google.com/github/1337Rinz/tool/blob/main/bgrm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#requirement
pip install rembg

# %%
from rembg import remove
from PIL import Image

# %%
#input path
input_path = '/content/atest.jpg'

#output save path
output_path = '/content/output.png'

# %%
inp = Image.open(input_path)

#remove bg
output = remove(inp)
output.save(output_path)

Image.open("output.png")
# Out:
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 42.6GB/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=420x417>
